# %% [markdown]
# # **Cradit Card Fraud Detection using ML**

# %% [markdown]
# **Import Libraries**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import plotly.express as px

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import IsolationForest
from sklearn.metrics import classification_report

# %% [markdown]
# **Connect to Drive**

# %%
df = pd.read_csv('/content/drive/MyDrive/ML(dataset)/fraudTest.csv')
test_df = pd.read_csv('/content/drive/MyDrive/ML(dataset)/fraudTest.csv')
df1 = pd.concat([df,test_df])

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Exploring the Dataset**

# %%
df1.shape
# Out:
# (1111438, 23)

# %%
df1.describe()
# Out:
#          Unnamed: 0        cc_num           amt           zip           lat  \
# count  1.111438e+06  1.111438e+06  1.111438e+06  1.111438e+06  1.111438e+06
# mean   2.778590e+05  4.178387e+17  6.939281e+01  4.884263e+04  3.854325e+01
# std    1.604223e+05  1.309836e+18  1.567459e+02  2.685527e+04  5.061334e+00
# min    0.000000e+00  6.041621e+10  1.000000e+00  1.257000e+03  2.002710e+01
# 25%    1.389292e+05  1.800429e+14  9.630000e+00  2.629200e+04  3.466890e+01
# 50%    2.778590e+05  3.521417e+15  4.729000e+01  4.817400e+04  3.937160e+01
# 75%    4.167888e+05  4.635331e+15  8.301000e+01  7.201100e+04  4.189480e+01
# max    5.557180e+05  4.992346e+18  2.276811e+04  9.992100e+04  6.568990e+01
#
#                long      city_pop     unix_time     merch_lat    merch_long  \
# count  1.111438e+06  1.111438e+06  1.111438e+06  1.111438e+06  1.111438e+06
# mean  -9.023133e+01  8.822189e+04  1.380679e+09  3.854280e+01 -9.023138e+01
# ...

# %% [markdown]
# **Checking for Null Values in Dataset**

# %%
df1 = df1.drop('Unnamed: 0', axis = 1)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1111438 entries, 0 to 555718
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   trans_date_trans_time  1111438 non-null  object
#  1   cc_num                 1111438 non-null  int64
#  2   merchant               1111438 non-null  object
#  3   category               1111438 non-null  object
#  4   amt                    1111438 non-null  float64
#  5   first                  1111438 non-null  object
#  6   last                   1111438 non-null  object
#  7   gender                 1111438 non-null  object
#  8   street                 1111438 non-null  object
#  9   city                   1111438 non-null  object
#  10  state                  1111438 non-null  object
#  11  zip                    1111438 non-null  int64
#  12  lat                    1111438 non-null  float64
#  13  long                   1111438 non-null  float64
# ...

# %%
df1.isna().sum()
# Out:
# trans_date_trans_time    0
# cc_num                   0
# merchant                 0
# category                 0
# amt                      0
# first                    0
# last                     0
# gender                   0
# street                   0
# city                     0
# state                    0
# zip                      0
# lat                      0
# long                     0
# city_pop                 0
# job                      0
# dob                      0
# trans_num                0
# unix_time                0
# merch_lat                0
# merch_long               0
# is_fraud                 0
# dtype: int64

# %% [markdown]
# **Females are doing more transactions but males are more likely to make fraud transaction**

# %%
fraud_counts = df1['is_fraud'].value_counts()

fig = px.pie(names=fraud_counts.index, values=fraud_counts.values, title='Fraudulent Transactions Distribution')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
le = LabelEncoder()
for column in df1.columns:
    if df1[column].dtype == 'object':
        df1[column] = le.fit_transform(df1[column])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1111438 entries, 0 to 555718
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   trans_date_trans_time  1111438 non-null  int64
#  1   cc_num                 1111438 non-null  int64
#  2   merchant               1111438 non-null  int64
#  3   category               1111438 non-null  int64
#  4   amt                    1111438 non-null  float64
#  5   first                  1111438 non-null  int64
#  6   last                   1111438 non-null  int64
#  7   gender                 1111438 non-null  int64
#  8   street                 1111438 non-null  int64
#  9   city                   1111438 non-null  int64
#  10  state                  1111438 non-null  int64
#  11  zip                    1111438 non-null  int64
#  12  lat                    1111438 non-null  float64
#  13  long                   1111438 non-null  float64
# ...

# %%
X_train, X_test = train_test_split(df1,test_size = 0.2, random_state = 42)

# %%
isf = IsolationForest()
isf.fit(X_train)
# Out:
# IsolationForest()

# %%
X_test['y_pred'] = isf.predict(X_test)

# %%
X_test['y_pred'] = X_test['y_pred'].replace({-1: 1, 1: 0})
X_test.head()
# Out:
#         trans_date_trans_time               cc_num  merchant  category    amt  \
# 293107                 288091  4400011257587661852       361         1   8.31
# 83332                   81790     6506116513503136       410         3  72.26
# 92802                   91044     4939976756738216       180         5  31.98
# 73342                   71962       30143535920989       210         0  25.22
# 439809                 432246     4378993458389626       305         5  39.56
#
#         first  last  gender  street  city  ...     long  city_pop  job  dob  \
# 293107    221   340       0     457   549  ... -98.7858       509  299  592
# 83332     196   354       0     611   776  ... -95.3031    144160  418  647
# 92802     238   218       0     344   662  ... -99.0025     18128  230  776
# 73342     213    78       0     422    91  ... -75.3478       504  155  590
# 439809    324   183       1     144   160  ... -71.1503      3807  423  888
#
# ...

# %%
y_pred = X_test['y_pred']
is_fraud = X_test['is_fraud']

report = classification_report(is_fraud, y_pred)

print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.75      0.86    221436
#            1       0.01      0.93      0.03       852
#
#     accuracy                           0.75    222288
#    macro avg       0.51      0.84      0.44    222288
# weighted avg       1.00      0.75      0.86    222288
